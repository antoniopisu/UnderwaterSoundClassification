# %%
import os
import shutil
import numpy as np
from tqdm import tqdm

def split_dataset(source_dir, destination_dir, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1, seed=42):
    np.random.seed(seed)  # Imposta il seme per la riproducibilità
    assert train_ratio + val_ratio + test_ratio == 1, "Le proporzioni devono sommare al 100%."
    
    # Creazione delle cartelle di destinazione per il training, validation e testing
    train_dir = os.path.join(destination_dir, 'Training')
    val_dir = os.path.join(destination_dir, 'Validation')
    test_dir = os.path.join(destination_dir, 'Testing')
    
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)
    
    for subdir, dirs, files in os.walk(source_dir):
        if files:
            # Calcolo il numero di file per ciascuna divisione
            num_files = len(files)
            num_train = int(num_files * train_ratio)
            num_val = int(num_files * val_ratio)
            num_test = num_files - num_train - num_val  # Il resto va nel test per evitare errori di arrotondamento

            # Mescolare i file per assicurare la casualità
            shuffled_files = np.random.permutation(files)

            # Assegna i file ai rispettivi set
            train_files = shuffled_files[:num_train]
            val_files = shuffled_files[num_train:num_train + num_val]
            test_files = shuffled_files[num_train + num_val:]

            # Creazione delle sottocartelle nel percorso di destinazione rispettando la struttura
            rel_path = os.path.relpath(subdir, source_dir)
            final_train_dir = os.path.join(train_dir, rel_path)
            final_val_dir = os.path.join(val_dir, rel_path)
            final_test_dir = os.path.join(test_dir, rel_path)
            
            os.makedirs(final_train_dir, exist_ok=True)
            os.makedirs(final_val_dir, exist_ok=True)
            os.makedirs(final_test_dir, exist_ok=True)

            # Spostamento dei file nelle rispettive cartelle
            for f in train_files:
                shutil.copy2(os.path.join(subdir, f), os.path.join(final_train_dir, f))
            for f in val_files:
                shutil.copy2(os.path.join(subdir, f), os.path.join(final_val_dir, f))
            for f in test_files:
                shutil.copy2(os.path.join(subdir, f), os.path.join(final_test_dir, f))

            print(f"Processati {len(files)} files in {subdir}")

source_directory = 'Dataset'
destination_directory = 'DividedDataset'

split_dataset(source_directory, destination_directory)
# Out:
# Processati 1 files in Dataset
# Processati 3 files in Dataset\Non-Target
# Processati 6 files in Dataset\Non-Target\Ambient Noise
# Processati 7 files in Dataset\Non-Target\Arnoux’s Beaked Whale
# Processati 60 files in Dataset\Non-Target\Atlantic Spotted Dolphin
# Processati 31 files in Dataset\Non-Target\Bearded Seal
# Processati 54 files in Dataset\Non-Target\Beluga, White Whale
# Processati 9 files in Dataset\Non-Target\Blue whale
# Processati 4 files in Dataset\Non-Target\Bocaccio
# Processati 28 files in Dataset\Non-Target\Bottlenose Dolphin
# Processati 52 files in Dataset\Non-Target\Bowhead Whale
# Processati 64 files in Dataset\Non-Target\Clymene Dolphin
# Processati 54 files in Dataset\Non-Target\Common Dolphin
# Processati 5 files in Dataset\Non-Target\Cuvier's beaked whale
# Processati 4 files in Dataset\Non-Target\Dugong
# Processati 7 files in Dataset\Non-Target\Dwarf Sperm Whale
# Processati 62 files in Dataset\Non-Target\False Killer Whale
# Processati 60 files in Dataset\Non-Target\Fin, Finback Whale
# Processati 5 files in Dataset\Non-Target\Fish chorus
# Processati 92 files in Dataset\Non-Target\Fraser_s Dolphin
# Processati 69 files in Dataset\Non-Target\Grampus, Risso_s Dolphin
# Processati 5 files in Dataset\Non-Target\Gray whale
# Processati 5 files in Dataset\Non-Target\Harbor Seals
# Processati 50 files in Dataset\Non-Target\Harp Seal
# Processati 92 files in Dataset\Non-Target\Humpback Whale
# Processati 10 files in Dataset\Non-Target\Indian Ocean Bottlenose Dolphin
# Processati 56 files in Dataset\Non-Target\Killer Whale
# Processati 16 files in Dataset\Non-Target\Leopard Seal
# Processati 73 files in Dataset\Non-Target\Long-Finned Pilot Whale
# Processati 57 files in Dataset\Non-Target\Melon Headed Whale
# Processati 27 files in Dataset\Non-Target\Minke Whale
# Processati 51 files in Dataset\Non-Target\Narwhal
# Processati 4 files in Dataset\Non-Target\New Zealand Fur Seal
# Processati 5 files in Dataset\Non-Target\Northern fur seal
# Processati 60 files in Dataset\Non-Target\Northern Right Whale
# Processati 15 files in Dataset\Non-Target\Odontocete
# Processati 4 files in Dataset\Non-Target\Other Animal Sounds
# Processati 47 files in Dataset\Non-Target\others
# Processati 66 files in Dataset\Non-Target\Pantropical Spotted Dolphin
# Processati 4 files in Dataset\Non-Target\Pilot Whale
# Processati 6 files in Dataset\Non-Target\Pygmy Blue Whale
# Processati 4 files in Dataset\Non-Target\Pygmy Killer Whale
# Processati 9 files in Dataset\Non-Target\Rain
# Processati 54 files in Dataset\Non-Target\Ross Seal
# Processati 51 files in Dataset\Non-Target\Rough-Toothed Dolphin
# Processati 5 files in Dataset\Non-Target\Short-beaked common dolphin
# Processati 67 files in Dataset\Non-Target\Short-Finned (Pacific) Pilot Whale
# Processati 8 files in Dataset\Non-Target\Snapping shrimp
# Processati 24 files in Dataset\Non-Target\Soundscape
# Processati 29 files in Dataset\Non-Target\Southern Right Whale
# Processati 65 files in Dataset\Non-Target\Sperm Whale
# Processati 115 files in Dataset\Non-Target\Spinner Dolphin
# Processati 86 files in Dataset\Non-Target\Striped Dolphin
# Processati 42 files in Dataset\Non-Target\Walrus
# Processati 9 files in Dataset\Non-Target\Weddell Seal
# Processati 60 files in Dataset\Non-Target\White-beaked Dolphin
# Processati 56 files in Dataset\Non-Target\White-sided Dolphin
# Processati 9 files in Dataset\Non-Target\Wind and wave
# Processati 3 files in Dataset\Target
# Processati 112 files in Dataset\Target\Cargo
# Processati 5 files in Dataset\Target\Echosounder
# Processati 13 files in Dataset\Target\others
# Processati 196 files in Dataset\Target\Passengership
# Processati 9 files in Dataset\Target\Sonar
# Processati 241 files in Dataset\Target\Tanker
# Processati 70 files in Dataset\Target\Tug
# Processati 26 files in Dataset\Target\Vessel
